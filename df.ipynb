# %%
import pandas as pd 


data =  pd.read_csv(r"D:\#PROJECTS\Road Accident Severity Prediction System\Road.csv\Road_encoded.csv")

data
# Out:
#        Age_band_of_driver  Educational_level  Driving_experience  \
# 0                       1                  5                   2
# 1                       2                  3                   5
# 2                       1                  3                   2
# 3                       1                  3                   4
# 4                       1                  3                   3
# ...                   ...                ...                 ...
# 12311                   2                  3                   3
# 12312                   1                  2                   4
# 12313                   3                  3                   4
# 12314                   1                  3                   5
# 12315                   1                  3                   4
#
#        Type_of_vehicle  Service_year_of_vehicle  Defect_of_vehicle  \
# 0                  0.1                        4                0.1
# ...
